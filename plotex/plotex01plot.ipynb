# %%
import matplotlib.pyplot as plt
import matplotlib as mpl #폰트를 설정하기 위한 import
import matplotlib.font_manager as fm  #어떤 폰트들이 있는지 알아보기 위해서 import
#[f.name for f in fm.fontManager.ttflist]  #list를 반복하는데 f에 담고 name값만 가져오겠다.
#fm.fontManager.ttflist
mpl.rcParams['font.family'] = 'Malgun Gothic' # AppleGothic ==> 맥에서는 맑은 고딕대신 사용
mpl.rcParams['axes.unicode_minus'] = False
mpl.rcParams['font.size'] = 10
plt.plot([-1,2,3,4,5],[-2,-4,6,8,12])
plt.title('꺽은선 그래프',fontdict={'family' :'HYMyeongJo-Extra','size' : 15, 'color' : 'teal'})
plt.show()
