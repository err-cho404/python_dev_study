# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.rcParams['font.family'] = 'Malgun Gothic' # AppleGothic ==> 맥에서는 맑은 고딕대신 사용
mpl.rcParams['axes.unicode_minus'] = False
mpl.rcParams['font.size'] = 10

#막대 그래프를 나타내기 위한 데이터
labels = ['강백호','서태웅','정대만']
values = [190,187,184]
plt.bar(labels,values,color = ['r','g','b'],alpha=0.4,width=0.5)
#plt.yticks(range(0,230,10))
plt.ylim(100,220)
#plt.xticks(labels,['1번','2번','3번'],rotation=90)
plt.show()
